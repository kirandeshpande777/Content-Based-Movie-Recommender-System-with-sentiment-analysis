# 156              Animation Adventure Family    Joel Crawford
# 157                             Music Drama      Liesl Tommy
# 158                                   Drama     Ridley Scott
# 159                           Drama Western  Paul Greengrass
#
#            actor_1_name       actor_2_name       actor_3_name
# 0    Andrea Riseborough      Demián Bichir           John Cho
# 1       Kristen Stewart     Vincent Cassel    Jessica Henwick
# 2       Tiffany Haddish         Rose Byrne        Salma Hayek
# 3         Josh Hartnett  Margarita Levieva     Chandler Riggs
# 4         Freya Tingley     Simon Abkarian       Rutger Hauer
# ..                  ...                ...                ...
# 155          Tom Cruise       Miles Teller  Jennifer Connelly
# 156        Nicolas Cage         Emma Stone      Ryan Reynolds
# 157     Jennifer Hudson    Forest Whitaker      Marlon Wayans
# 158          Matt Damon        Adam Driver        Jodie Comer
# 159           Tom Hanks      Helena Zengel    Neil Sandilands
#
# [160 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','Genre','movie_title']]

# %%
new_df20
# Out:
#        director_name        actor_1_name       actor_2_name  \
# 0      Nicolas Pesce  Andrea Riseborough      Demián Bichir
# 1     William Eubank     Kristen Stewart     Vincent Cassel
# 2      Miguel Arteta     Tiffany Haddish         Rose Byrne
# 3     Anthony Jerjen       Josh Hartnett  Margarita Levieva
# 4     Andrew Desmond       Freya Tingley     Simon Abkarian
# ..               ...                 ...                ...
# 155  Joseph Kosinski          Tom Cruise       Miles Teller
# 156    Joel Crawford        Nicolas Cage         Emma Stone
# 157      Liesl Tommy     Jennifer Hudson    Forest Whitaker
# 158     Ridley Scott          Matt Damon        Adam Driver
# 159  Paul Greengrass           Tom Hanks      Helena Zengel
#
#           actor_3_name                                   Genre  \
# 0             John Cho                          Horror Mystery
# 1      Jessica Henwick  Action Horror Science Fiction Thriller
# 2          Salma Hayek                                  Comedy
# 3       Chandler Riggs                    Drama Thriller Crime
# 4         Rutger Hauer                 Horror Thriller Mystery
# ..                 ...                                     ...
# 155  Jennifer Connelly                            Action Drama
# 156      Ryan Reynolds              Animation Adventure Family
# 157      Marlon Wayans                             Music Drama
# 158        Jodie Comer                                   Drama
# 159    Neil Sandilands                           Drama Western
#
#            movie_title
# 0           The Grudge
# 1           Underwater
# 2          Like a Boss
# 3    Inherit the Viper
# 4           The Sonata
# ..                 ...
# 155  Top Gun: Maverick
# 156       The Croods 2
# 157            Respect
# 158      The Last Duel
# 159  News of the World
#
# [160 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['Genre']

# %%
new_df20['actor_2_name'] = new_df20['actor_2_name'].replace(np.nan, 'unknown')
new_df20['actor_3_name'] = new_df20['actor_3_name'].replace(np.nan, 'unknown')
new_df20['director_name'] = new_df20['director_name'].replace(np.nan, 'unknown')
new_df20['movie_title'] = new_df20['movie_title'].replace(np.nan, 'unknown')
new_df20['actor_1_name'] = new_df20['actor_1_name'].replace(np.nan, 'unknown')
new_df20['comb'] = new_df20['comb'].replace(np.nan, 'unknown')
new_df20['Genre'] = new_df20['Genre'].replace(np.nan, 'unknown')

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#        director_name        actor_1_name       actor_2_name  \
# 0      Nicolas Pesce  Andrea Riseborough      Demián Bichir
# 1     William Eubank     Kristen Stewart     Vincent Cassel
# 2      Miguel Arteta     Tiffany Haddish         Rose Byrne
# 3     Anthony Jerjen       Josh Hartnett  Margarita Levieva
# 4     Andrew Desmond       Freya Tingley     Simon Abkarian
# ..               ...                 ...                ...
# 155  Joseph Kosinski          Tom Cruise       Miles Teller
# 156    Joel Crawford        Nicolas Cage         Emma Stone
# 157      Liesl Tommy     Jennifer Hudson    Forest Whitaker
# 158     Ridley Scott          Matt Damon        Adam Driver
# 159  Paul Greengrass           Tom Hanks      Helena Zengel
#
#           actor_3_name                                   Genre  \
# 0             John Cho                          Horror Mystery
# 1      Jessica Henwick  Action Horror Science Fiction Thriller
# 2          Salma Hayek                                  Comedy
# 3       Chandler Riggs                    Drama Thriller Crime
# 4         Rutger Hauer                 Horror Thriller Mystery
# ..                 ...                                     ...
# 155  Jennifer Connelly                            Action Drama
# 156      Ryan Reynolds              Animation Adventure Family
# 157      Marlon Wayans                             Music Drama
# 158        Jodie Comer                                   Drama
# 159    Neil Sandilands                           Drama Western
#
#            movie_title                                               comb
# 0           the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1           underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2          like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3    inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# 4           the sonata  Freya Tingley Simon Abkarian Rutger Hauer Andr...
# ..                 ...                                                ...
# 155  top gun: maverick  Tom Cruise Miles Teller Jennifer Connelly Jose...
# 156       the croods 2  Nicolas Cage Emma Stone Ryan Reynolds Joel Cra...
# 157            respect  Jennifer Hudson Forest Whitaker Marlon Wayans ...
# 158      the last duel  Matt Damon Adam Driver Jodie Comer Ridley Scot...
# 159  news of the world  Tom Hanks Helena Zengel Neil Sandilands Paul G...
#
# [160 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#       color          director_name  num_critic_for_reviews  duration  \
# 0     Color          James Cameron                   723.0     178.0
# 1     Color         Gore Verbinski                   302.0     169.0
# 2     Color             Sam Mendes                   602.0     148.0
# 3     Color      Christopher Nolan                   813.0     164.0
# 4       NaN            Doug Walker                     NaN       NaN
# ...     ...                    ...                     ...       ...
# 5879    NaN           Greta Gerwig                     NaN       NaN
# 5880    NaN             Sam Mendes                     NaN       NaN
# 5881    NaN  Destin Daniel Cretton                     NaN       NaN
# 5882    NaN        Chinonye Chukwu                     NaN       NaN
# 5883    NaN           Waymon Boone                     NaN       NaN
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 0                         0.0                   855.0      Joel David Moore
# 1                       563.0                  1000.0         Orlando Bloom
# 2                         0.0                   161.0          Rory Kinnear
# 3                     22000.0                 23000.0        Christian Bale
# 4                       131.0                     NaN            Rob Walker
# ...                       ...                     ...                   ...
# 5879                      NaN                     NaN           Emma Watson
# 5880                      NaN                     NaN  Dean-Charles Chapman
# 5881                      NaN                     NaN            Jamie Foxx
# 5882                      NaN                     NaN        Wendell Pierce
# 5883                      NaN                     NaN          Kevin Pollak
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 5879                     NaN          NaN                              NaN
# 5880                     NaN          NaN                              NaN
# 5881                     NaN          NaN                              NaN
# 5882                     NaN          NaN                              NaN
# 5883                     NaN          NaN                              NaN
#
#       ... country content_rating       budget  title_year  \
# 0     ...     USA          PG-13  237000000.0      2009.0
# 1     ...     USA          PG-13  300000000.0      2007.0
# 2     ...      UK          PG-13  245000000.0      2015.0
# 3     ...     USA          PG-13  250000000.0      2012.0
# 4     ...     NaN            NaN          NaN         NaN
# ...   ...     ...            ...          ...         ...
# 5879  ...     NaN            NaN          NaN         NaN
# 5880  ...     NaN            NaN          NaN         NaN
# 5881  ...     NaN            NaN          NaN         NaN
# 5882  ...     NaN            NaN          NaN         NaN
# 5883  ...     NaN            NaN          NaN         NaN
#
#      actor_2_facebook_likes  imdb_score aspect_ratio movie_facebook_likes  \
# 0                     936.0         7.9         1.78              33000.0
# 1                    5000.0         7.1         2.35                  0.0
# 2                     393.0         6.8         2.35              85000.0
# 3                   23000.0         8.5         2.35             164000.0
# 4                      12.0         7.1          NaN                  0.0
# ...                     ...         ...          ...                  ...
# 5879                    NaN         NaN          NaN                  NaN
# 5880                    NaN         NaN          NaN                  NaN
# 5881                    NaN         NaN          NaN                  NaN
# 5882                    NaN         NaN          NaN                  NaN
# 5883                    NaN         NaN          NaN                  NaN
#
#                                                    comb  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5879  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5880  George MacKay Dean-Charles Chapman Mark Strong...
# 5881  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5882  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 5883  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
#                          Genre
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 5879             Drama Romance
# 5880  War Drama Action History
# 5881               Drama Crime
# 5882                     Drama
# 5883           Horror Thriller
#
# [5884 rows x 30 columns]

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 6039    NaN    Joseph Kosinski                     NaN       NaN
# 6040    NaN      Joel Crawford                     NaN       NaN
# 6041    NaN        Liesl Tommy                     NaN       NaN
# 6042    NaN       Ridley Scott                     NaN       NaN
# 6043    NaN    Paul Greengrass                     NaN       NaN
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 6039                      NaN                     NaN      Miles Teller
# 6040                      NaN                     NaN        Emma Stone
# 6041                      NaN                     NaN   Forest Whitaker
# 6042                      NaN                     NaN       Adam Driver
# 6043                      NaN                     NaN     Helena Zengel
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 6039                     NaN          NaN                              NaN
# 6040                     NaN          NaN                              NaN
# 6041                     NaN          NaN                              NaN
# 6042                     NaN          NaN                              NaN
# 6043                     NaN          NaN                              NaN
#
#       ... country content_rating       budget  title_year  \
# 0     ...     USA          PG-13  237000000.0      2009.0
# 1     ...     USA          PG-13  300000000.0      2007.0
# 2     ...      UK          PG-13  245000000.0      2015.0
# 3     ...     USA          PG-13  250000000.0      2012.0
# 4     ...     NaN            NaN          NaN         NaN
# ...   ...     ...            ...          ...         ...
# 6039  ...     NaN            NaN          NaN         NaN
# 6040  ...     NaN            NaN          NaN         NaN
# 6041  ...     NaN            NaN          NaN         NaN
# 6042  ...     NaN            NaN          NaN         NaN
# 6043  ...     NaN            NaN          NaN         NaN
#
#      actor_2_facebook_likes  imdb_score aspect_ratio movie_facebook_likes  \
# 0                     936.0         7.9         1.78              33000.0
# 1                    5000.0         7.1         2.35                  0.0
# 2                     393.0         6.8         2.35              85000.0
# 3                   23000.0         8.5         2.35             164000.0
# 4                      12.0         7.1          NaN                  0.0
# ...                     ...         ...          ...                  ...
# 6039                    NaN         NaN          NaN                  NaN
# 6040                    NaN         NaN          NaN                  NaN
# 6041                    NaN         NaN          NaN                  NaN
# 6042                    NaN         NaN          NaN                  NaN
# 6043                    NaN         NaN          NaN                  NaN
#
#                                                    comb  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6039  Tom Cruise Miles Teller Jennifer Connelly Jose...
# 6040  Nicolas Cage Emma Stone Ryan Reynolds Joel Cra...
# 6041  Jennifer Hudson Forest Whitaker Marlon Wayans ...
# 6042  Matt Damon Adam Driver Jodie Comer Ridley Scot...
# 6043  Tom Hanks Helena Zengel Neil Sandilands Paul G...
#
#                            Genre
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 6039                Action Drama
# 6040  Animation Adventure Family
# 6041                 Music Drama
# 6042                       Drama
# 6043               Drama Western
#
# [6044 rows x 30 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
